# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Bitcoin.csv')

# %%
def checkmove(row):
    if row['open'] < row['close']:
        return 'Apreciated'
    elif row['open'] > row['close']:
        return 'Depreciated'
    else:
        return 'Same'
    
df['movement'] = df.apply(checkmove, axis=1)

# %%
df.drop(columns= ['date']).groupby('movement').agg(['count', 'mean'])
# Out:
#              open                high                 low               close  \
#             count          mean count          mean count          mean count
# movement
# Apreciated   1858  15240.782363  1858  15793.496997  1858  15067.251432  1858
# Depreciated  1649  16722.959727  1649  16893.268975  1649  16070.627101  1649
# Same            1    334.590000     1    336.530000     1    330.640000     1
#
#
#                      mean
# movement
# Apreciated   15631.101523
# Depreciated  16319.212887
# Same           334.590000

# %%
def percentege(row):
    theper = (((row['close']-row['open'])/row['close'])*100)
    return round(theper, 2)
df['percent'] = df.apply(percentege, axis=1)

# %%
df['date'] = df['date'].apply(pd.to_datetime)

# %%
df['week_day'] = df['date'].dt.day_name()

# %%
outOfCurve = df[df['percent'] > 10]
display(outOfCurve)
len(df[df['percent'] > 10])
# Out:
#            date      open      high       low     close    movement  percent  \
# 786  2022-02-28  37706.00  43760.46  37518.21  43193.23  Apreciated    12.70
# 810  2022-02-04  37149.27  41527.79  37093.63  41500.88  Apreciated    10.49
# 1050 2021-06-09  33416.98  37537.37  32475.87  37345.12  Apreciated    10.52
# 1066 2021-05-24  34700.36  39835.14  34551.08  38705.98  Apreciated    10.35
# 1171 2021-02-08  38886.83  46203.93  38076.32  46196.46  Apreciated    15.82
# 1456 2020-04-29   7806.71   8871.75   7786.05   8801.04  Apreciated    11.30
# 1497 2020-03-19   5245.42   6329.74   5236.97   6191.19  Apreciated    15.28
# 1643 2019-10-25   7490.70   8691.54   7479.98   8660.70  Apreciated    13.51
# 1762 2019-06-28  11162.17  12445.17  10914.50  12407.33  Apreciated    10.04
# 1802 2019-05-19   7267.96   8261.94   7267.96   8197.69  Apreciated    11.34
# 1808 2019-05-13   6971.18   8047.41   6898.28   7814.92  Apreciated    10.80
# 1810 2019-05-11   6379.67   7333.00   6375.70   7204.77  Apreciated    11.45
# 1849 2019-04-02   4156.92   4905.95   4155.32   4879.88  Apreciated    14.82
# 1974 2018-11-28   3822.47   4385.90   3822.47   4257.42  Apreciated    10.22
# 2204 2018-04-12   6955.38   7899.23   6806.51   7889.25  Apreciated    11.84
# 2301 2018-01-05  15477.20  17705.20  15202.80  17429.50  Apreciated    11.20
# 2311 2017-12-26  14036.60  16461.20  14028.90  16099.80  Apreciated    12.82
# 2330 2017-12-07  14266.10  17899.70  14057.30  17899.70  Apreciated    20.30
# 2331 2017-12-06  11923.40  14369.10  11923.40  14291.50  Apreciated    16.57
# 2386 2017-10-12   4829.58   5446.91   4822.00   5446.91  Apreciated    11.33
# 2410 2017-09-18   3591.09   4079.23   3591.09   4065.20  Apreciated    11.66
# 2413 2017-09-15   3166.30   3733.45   2946.62   3637.52  Apreciated    12.95
# 2454 2017-08-05   2897.63   3290.01   2874.83   3252.91  Apreciated    10.92
# 2470 2017-07-20   2269.89   2900.70   2269.89   2817.60  Apreciated    19.44
# 2473 2017-07-17   1932.62   2230.49   1932.62   2228.41  Apreciated    13.27
# 2888 2016-05-28    473.03    533.47    472.70    530.04  Apreciated    10.76
# 3095 2015-11-03    361.87    417.90    357.65    403.42  Apreciated    10.30
# 3387 2015-01-15    176.90    229.07    176.90    209.84  Apreciated    15.70
# 3451 2014-11-12    367.98    429.72    367.98    423.56  Apreciated    13.12
#
#        week_day
# 786      Monday
# 810      Friday
# 1050  Wednesday
# 1066     Monday
# 1171     Monday
# 1456  Wednesday
# 1497   Thursday
# 1643     Friday
# 1762     Friday
# 1802     Sunday
# 1808     Monday
# 1810   Saturday
# 1849    Tuesday
# 1974  Wednesday
# 2204   Thursday
# 2301     Friday
# 2311    Tuesday
# 2330   Thursday
# 2331  Wednesday
# 2386   Thursday
# 2410     Monday
# 2413     Friday
# 2454   Saturday
# 2470   Thursday
# 2473     Monday
# 2888   Saturday
# 3095    Tuesday
# 3387   Thursday
# 3451  Wednesday
# 29

# %%
df['week_day'] = df['date'].dt.day_name()

# %%
moveToWeek = df.groupby(['week_day','movement']).agg('count')['close']
display(moveToWeek)
(moveToWeek.loc['Friday','Apreciated']/len(df))*100
# Out:
# week_day   movement
# Friday     Apreciated     276
#            Depreciated    225
# Monday     Apreciated     272
#            Depreciated    229
# Saturday   Apreciated     278
#            Depreciated    223
# Sunday     Apreciated     255
#            Depreciated    246
# Thursday   Apreciated     254
#            Depreciated    247
# Tuesday    Apreciated     265
#            Depreciated    236
# Wednesday  Apreciated     258
#            Depreciated    243
#            Same             1
# Name: close, dtype: int64
# 7.8677309007981755

# %%
df.groupby('movement').agg('count')['close']['Apreciated']
# Out:
# 1858

# %%
depreciated = {}
apreciated = {}
key = 0
for i in moveToWeek.items():
    toWhole = ((moveToWeek[i[0]]/len(df))*100)
    if i[0][1] == 'Apreciated':
        toMove = ((moveToWeek[i[0]]/(df.groupby('movement').agg('count')['close'][i[0][1]]))*100)
        apreciated[key] = {i[0][0]: round(toWhole, 2),
                           'To Move': round(toMove, 2)
                           }
    elif i[0][1] == 'Same':
        continue
    else:
        toMove = ((moveToWeek[i[0]]/(df.groupby('movement').agg('count')['close'][i[0][1]]))*100)
        depreciated[key] = {i[0][0]: round(toWhole, 2),
                           'To Move': round(toMove, 2)
                           }
    key+=1
        
display(apreciated)
display(depreciated)
# Out:
# {0: {'Friday': 7.87, 'To Move': 14.85},
#  2: {'Monday': 7.75, 'To Move': 14.64},
#  4: {'Saturday': 7.92, 'To Move': 14.96},
#  6: {'Sunday': 7.27, 'To Move': 13.72},
#  8: {'Thursday': 7.24, 'To Move': 13.67},
#  10: {'Tuesday': 7.55, 'To Move': 14.26},
#  12: {'Wednesday': 7.35, 'To Move': 13.89}}
# {1: {'Friday': 6.41, 'To Move': 13.64},
#  3: {'Monday': 6.53, 'To Move': 13.89},
#  5: {'Saturday': 6.36, 'To Move': 13.52},
#  7: {'Sunday': 7.01, 'To Move': 14.92},
#  9: {'Thursday': 7.04, 'To Move': 14.98},
#  11: {'Tuesday': 6.73, 'To Move': 14.31},
#  13: {'Wednesday': 6.93, 'To Move': 14.74}}

# %%
df
# Out:
#            date      open      high       low     close     movement  percent  \
# 0    2024-04-24  66420.40  67053.77  63702.55  64317.48  Depreciated    -3.27
# 1    2024-04-23  66839.89  67199.24  65864.87  66407.27  Depreciated    -0.65
# 2    2024-04-22  64935.63  67233.96  64548.18  66837.68   Apreciated     2.85
# 3    2024-04-21  64992.82  65723.24  64277.72  64926.64  Depreciated    -0.10
# 4    2024-04-20  63851.10  65442.46  63172.40  64994.44   Apreciated     1.76
# ...         ...       ...       ...       ...       ...          ...      ...
# 3503 2014-09-21    408.08    412.43    393.18    398.82  Depreciated    -2.32
# 3504 2014-09-20    394.67    423.30    389.88    408.90   Apreciated     3.48
# 3505 2014-09-19    424.10    427.83    384.53    394.80  Depreciated    -7.42
# 3506 2014-09-18    456.86    456.86    413.10    424.44  Depreciated    -7.64
# 3507 2014-09-17    465.86    468.17    452.42    457.33  Depreciated    -1.87
#
#        week_day
# 0     Wednesday
# 1       Tuesday
# 2        Monday
# 3        Sunday
# 4      Saturday
# ...         ...
# 3503     Sunday
# 3504   Saturday
# 3505     Friday
# 3506   Thursday
# 3507  Wednesday
#
# [3508 rows x 8 columns]

# %%
# The idea here is to create an identifier that enables us to group days by week.
# So were creating 2 columns, iso_week and iso_year for that purpose.
df = df.sort_values(by="date")
df['iso_year'] = df['date'].dt.isocalendar().year
df['iso_week'] = df['date'].dt.isocalendar().week

# Create a unique identifier for each ISO year-week combination
df['iso_year_week'] = df['iso_year'].astype(str) + '_W' + df['iso_week'].astype(str)
df
# Out:
#            date      open      high       low     close     movement  percent  \
# 3507 2014-09-17    465.86    468.17    452.42    457.33  Depreciated    -1.87
# 3506 2014-09-18    456.86    456.86    413.10    424.44  Depreciated    -7.64
# 3505 2014-09-19    424.10    427.83    384.53    394.80  Depreciated    -7.42
# 3504 2014-09-20    394.67    423.30    389.88    408.90   Apreciated     3.48
# 3503 2014-09-21    408.08    412.43    393.18    398.82  Depreciated    -2.32
# ...         ...       ...       ...       ...       ...          ...      ...
# 4    2024-04-20  63851.10  65442.46  63172.40  64994.44   Apreciated     1.76
# 3    2024-04-21  64992.82  65723.24  64277.72  64926.64  Depreciated    -0.10
# 2    2024-04-22  64935.63  67233.96  64548.18  66837.68   Apreciated     2.85
# 1    2024-04-23  66839.89  67199.24  65864.87  66407.27  Depreciated    -0.65
# 0    2024-04-24  66420.40  67053.77  63702.55  64317.48  Depreciated    -3.27
#
#        week_day  iso_year  iso_week iso_year_week
# 3507  Wednesday      2014        38      2014_W38
# 3506   Thursday      2014        38      2014_W38
# 3505     Friday      2014        38      2014_W38
# 3504   Saturday      2014        38      2014_W38
# 3503     Sunday      2014        38      2014_W38
# ...         ...       ...       ...           ...
# 4      Saturday      2024        16      2024_W16
# 3        Sunday      2024        16      2024_W16
# 2        Monday      2024        17      2024_W17
# 1       Tuesday      2024        17      2024_W17
# 0     Wednesday      2024        17      2024_W17
#
# [3508 rows x 11 columns]

# %%
highest_price_daypweek = df.groupby(["iso_year_week", "week_day"])["high"].agg("min").reset_index()

lowest_price_daypweek = df.groupby(["iso_year_week", "week_day"])["low"].agg("min").reset_index()
lowest_price_daypweek
# Out:
#      iso_year_week   week_day       low
# 0         2014_W38     Friday    384.53
# 1         2014_W38   Saturday    389.88
# 2         2014_W38     Sunday    393.18
# 3         2014_W38   Thursday    413.10
# 4         2014_W38  Wednesday    452.42
# ...            ...        ...       ...
# 3503       2024_W9   Saturday  61657.29
# 3504       2024_W9     Sunday  61435.02
# 3505       2024_W9   Thursday  60498.73
# 3506       2024_W9    Tuesday  54484.20
# 3507       2024_W9  Wednesday  56738.43
#
# [3508 rows x 3 columns]

# %%
index_keep_high = highest_price_daypweek.groupby("iso_year_week")["high"].idxmax().values
index_keep_low = lowest_price_daypweek.groupby("iso_year_week")["low"].idxmin().values

# %%
max_per_week = highest_price_daypweek.loc[index_keep_high]
weekday_count = max_per_week["week_day"].value_counts()
total_count = weekday_count.sum()
day_percentages = (weekday_count/ total_count) * 100

desired_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
day_series_sorted = day_percentages.reindex(desired_order)
x = day_series_sorted
x = x.reset_index()
x.columns = ["week_day", "percentage"]
x
# Out:
#     week_day  percentage
# 0     Monday   25.498008
# 1    Tuesday   12.749004
# 2  Wednesday   11.354582
# 3   Thursday    9.760956
# 4     Friday    9.561753
# 5   Saturday   11.354582
# 6     Sunday   19.721116

# %%
plt.bar(x["week_day"], x["percentage"] )
plt.title("Probability of 'day' setting the high of the week on BTC")
plt.ylabel("Percent %", rotation = "vertical")
plt.xticks(desired_order, labels=["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"])
# Out:
# ([<matplotlib.axis.XTick at 0x23f0c187d60>,
#   <matplotlib.axis.XTick at 0x23f0c187d30>,
#   <matplotlib.axis.XTick at 0x23f0c187520>,
#   <matplotlib.axis.XTick at 0x23f0c47edf0>,
#   <matplotlib.axis.XTick at 0x23f0c4418e0>,
#   <matplotlib.axis.XTick at 0x23f0c46d3d0>,
#   <matplotlib.axis.XTick at 0x23f0c46de80>],
#  [Text(0.0, 0, 'Mon'),
#   Text(1.0, 0, 'Tue'),
#   Text(2.0, 0, 'Wed'),
#   Text(3.0, 0, 'Thu'),
#   Text(4.0, 0, 'Fri'),
#   Text(5.0, 0, 'Sat'),
#   Text(6.0, 0, 'Sun')])

# %%
min_per_week = lowest_price_daypweek.loc[index_keep_low]
weekday_count_min = min_per_week["week_day"].value_counts()
total_count_min = weekday_count_min.sum()
day_percentages_min = (weekday_count_min/ total_count_min) * 100
day_percentages_min

day_series_sorted = day_percentages_min.reindex(desired_order)
x = day_series_sorted
x = x.reset_index()
x.columns = ["week_day", "percentage"]

plt.bar(x["week_day"], x["percentage"] )
plt.title("Probability of 'day' setting the low of the week on BTC")
plt.ylabel("Percent %", rotation = "vertical")
plt.xticks(desired_order, labels=["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"])
# Out:
# ([<matplotlib.axis.XTick at 0x23f0c55ffd0>,
#   <matplotlib.axis.XTick at 0x23f0c55ffa0>,
#   <matplotlib.axis.XTick at 0x23f0c55f790>,
#   <matplotlib.axis.XTick at 0x23f0d7acca0>,
#   <matplotlib.axis.XTick at 0x23f0d7b1af0>,
#   <matplotlib.axis.XTick at 0x23f0d7a45e0>,
#   <matplotlib.axis.XTick at 0x23f0d7a4d30>],
#  [Text(0.0, 0, 'Mon'),
#   Text(1.0, 0, 'Tue'),
#   Text(2.0, 0, 'Wed'),
#   Text(3.0, 0, 'Thu'),
#   Text(4.0, 0, 'Fri'),
#   Text(5.0, 0, 'Sat'),
#   Text(6.0, 0, 'Sun')])
