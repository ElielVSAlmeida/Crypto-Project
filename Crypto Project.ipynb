# %%
import pandas as pd
import requests
import json
from bs4 import BeautifulSoup

# %%
url = 'https://finance.yahoo.com/quote/BTC-USD/history/?period1=1410912000&period2=1713963810'
agent = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'}
response = requests.get(url, headers= agent)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
items = soup.find_all('td', attrs= {'class': 'svelte-ewueuo'})
items[0].get_text()
# Out:
# 'Apr 24, 2024'

# %%
key = 0
df = {}
for i in items:
    if items.index(i) == 0 or items.index(i) % 7 == 0:
        data = i.get_text()
    elif items.index(i) == 4536:
        break
    
    df[key] = {
        'data': data
    }
    key+= 1
    
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[79], line 4
#       2 df = {}
#       3 for i in items:
# ----> 4     if items.index(i) == 0 or items.index(i) % 7 == 0:
#       5         data = i.get_text()
#       6     elif items.index(i) == 4536:
#
# File ~\anaconda3\Lib\site-packages\bs4\element.py:1634, in Tag.__eq__(self, other)
#    1627 if self is other:
#    1628     return True
#    1629 if (not hasattr(other, 'name') or
#    1630     not hasattr(other, 'attrs') or
#    1631     not hasattr(other, 'contents') or
#    1632     self.name != other.name or
#    1633     self.attrs != other.attrs or
# -> 1634     len(self) != len(other)):
#    1635     return False
#    1636 for i, my_child in enumerate(self.contents):
#
# File ~\anaconda3\Lib\site-packages\bs4\element.py:1579, in Tag.__len__(self)
#    1576     "Iterating over a Tag iterates over its contents."
# ...

# %%
if items.index(items[7]) == 0 or items.index(items[7]) % 7 == 0:
    print('slk ', items[7] )
else:
    print('aff')
# Out:
# slk  <td class="svelte-ewueuo">Apr 23, 2024</td>

# %%
items[70]
# Out:
# <td class="svelte-ewueuo">Apr 14, 2024</td>

# %%
url = "https://working-days.p.rapidapi.com/1.3/get_array_info_day"

querystring = {"start_date":"2013-01-01","end_date":"2013-01-31","country_code":"US"}

headers = {
    "X-RapidAPI-Key": "f6a9d0c2e0msh678639f9304e347p10a4bajsn8cd1e7cfd4a0",
    "X-RapidAPI-Host": "working-days.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

r = response.json()

# %%
r
# Out:
# {'days': [{'date': '2013-01-01',
#    'working_day': 0,
#    'work_hours': 0,
#    'wages': 0,
#    'morning_start': '',
#    'morning_end': '',
#    'afternoon_start': '',
#    'afternoon_end': '',
#    'public_holiday': '1',
#    'public_holiday_description': "New Year's Day",
#    'public_holiday_short_description': "New Year's Day",
#    'weekend_day': 0,
#    'custom_date': 0,
#    'custom_date_description': '',
#    'custom_date_color': '',
#    'type': 2},
#   {'date': '2013-01-02',
#    'working_day': 1,
#    'work_hours': 8,
#    'wages': 160,
#    'morning_start': '08:00',
#    'morning_end': '12:00',
#    'afternoon_start': '14:00',
#    'afternoon_end': '18:00',
#    'public_holiday': '0',
#    'public_holiday_description': '',
#    'public_holiday_short_description': '',
#    'weekend_day': 0,
#    'custom_date': 0,
#    'custom_date_description': '',
#    'custom_date_color': '',
#    'type': 32},
#   {'date': '2013-01-03',
#    'working_day': 1,
#    'work_hours': 8,
# ...
